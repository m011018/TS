# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import math
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing diesel data

# %%
# Read the data to a pandas data frame
df_diesel = pd.read_csv('..\data\Diesel.csv', 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_diesel
# Out:
#            Datum                     brand  \
# 0     21.09.2020         Alpina Tankstelle
# 1     04.07.2022                       Eni
# 2     15.06.2022                    Tamoil
# 3     02.06.2022  BP Service Weinland West
# 4     02.06.2022   BP Service Weinland Ost
# ...          ...                       ...
# 2600  04.05.2016               Auto Lugano
# 2601  26.12.2020           Lang Energie AG
# 2602  22.12.2020              Ruedi Rüssel
# 2603  22.12.2020       Dorfgarage Willi AG
# 2604  21.09.2020         Alpina Tankstelle
#
#                                    addresse  diesel
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120
# 1             Rte d'Aigle 18, 1867 Ollon VD   2.450
# 2      Rte du Nant-d'Avril 36, 1214 Vernier   2.440
# 3     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# 4     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# ...                                     ...     ...
# 2600           Via Cantonale, 6983 Magliaso   1.319
# 2601           Seestr. 13, 8280 Kreuzlingen   1.310
# 2602           Luzernstr. 60, 4553 Subingen   1.310
# 2603     Rheintalstrasse 59, 5325 Leibstadt   1.300
# 2604      Dorfstrasse 42, 7563 Samnaun Dorf   1.120
#
# [2605 rows x 4 columns]

# %% [markdown]
# # Importing bleifrei data

# %%
# Read the data to a pandas data frame
df_bleifrei = pd.read_csv("..\data\Bleifrei.csv", 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_bleifrei
# Out:
#            Datum                                brand  \
# 0     21.09.2020                    Alpina Tankstelle
# 1     04.07.2022                               Tamoil
# 2     04.07.2022                               Agrola
# 3     04.07.2022                    Garage Blatter AG
# 4     11.07.2022                     Garage Gasparini
# ...          ...                                  ...
# 2599  22.12.2020                         Ruedi Rüssel
# 2600  22.12.2020                  Dorfgarage Willi AG
# 2601  24.07.2016                        Garage Jaques
# 2602  27.11.2020  Hansruedi Julmi Garage & Tankstelle
# 2603  21.09.2020                    Alpina Tankstelle
#
#                                    addresse  bleifrei
# 0         Dorfstrasse 42, 7563 Samnaun Dorf      1.14
# 1     Gsteigstr. 174, 3785 Gsteig b. Gstaad      2.23
# 2               Kantonsstr. 50, 3930 Eyholz      2.23
# 3                 Ennet Brücke 7, 3930 Visp      2.23
# 4                  Veia Granda, 7440 Andeer      2.23
# ...                                     ...       ...
# 2599           Luzernstr. 60, 4553 Subingen      1.26
# 2600     Rheintalstrasse 59, 5325 Leibstadt      1.25
# 2601           Route de Lausanne, 1260 Nyon      1.25
# 2602         Bielstrasse 85, 2542 Pieterlen      1.25
# 2603      Dorfstrasse 42, 7563 Samnaun Dorf      1.14
#
# [2604 rows x 4 columns]

# %%
df = df_diesel.merge(df_bleifrei)

df
# Out:
#            Datum                      brand  \
# 0     21.09.2020          Alpina Tankstelle
# 1     21.09.2020          Alpina Tankstelle
# 2     21.09.2020          Alpina Tankstelle
# 3     21.09.2020          Alpina Tankstelle
# 4     21.09.2020          Alpina Tankstelle
# ...          ...                        ...
# 2408  04.05.2016  Auto Bellinzona Nord Sagl
# 2409  02.02.2016                  Reisch AG
# 2410  04.05.2016                Auto Lugano
# 2411  22.12.2020               Ruedi Rüssel
# 2412  22.12.2020        Dorfgarage Willi AG
#
#                                    addresse  diesel  bleifrei
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 1         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 2         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 3         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 4         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# ...                                     ...     ...       ...
# 2408   Via S. Gottardo 57B, 6500 Bellinzona   1.320     1.330
# 2409       Hauptstr. 24, 8573 Siegershausen   1.320     1.270
# 2410           Via Cantonale, 6983 Magliaso   1.319     1.279
# 2411           Luzernstr. 60, 4553 Subingen   1.310     1.260
# 2412     Rheintalstrasse 59, 5325 Leibstadt   1.300     1.250
#
# [2413 rows x 5 columns]

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['addresse'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['addresse']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['addresse'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
# Out:
# Geocoding address 2413 out of 2413 : Rheintalstrasse 59, 5325 Leibstadt

# %%
counter=0;
count=0;
count2=0;

for i in df['lat']:
    if math.isnan(i):
        count = count + 1
    else:
        count2 = count2 + 1
        
    counter = counter + 1
    
print(count)
print(count2)
# Out:
# 619
# 1794

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['addresse']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e61f6ade344f2af60217e7797c0cc42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e61f6ade344f2af60217e7797c0cc42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e61f6ade344f2af60217e7797c0cc42 = L.map(
#                 &quot;map_1e61f6ade344f2af60217e7797c0cc42&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_945ce7b554bf69ade1e26821bceff5ff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1e61f6ade344f2af60217e7797c0cc42);
#
#
#             var marker_7fe2b12fbad5b698749f89a7f8ec4cec = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_1e61f6ade344f2af60217e7797c0cc42);
#
#
#         var popup_e05249ecf49fed9abeea5481a614bbf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cc18224e8be65b6c132c891c58241179 = $(`&lt;div id=&quot;html_cc18224e8be65b6c132c891c58241179&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_e05249ecf49fed9abeea5481a614bbf1.setContent(html_cc18224e8be65b6c132c891c58241179);
#
#
#         marker_7fe2b12fbad5b698749f89a7f8ec4cec.bindPopup(popup_e05249ecf49fed9abeea5481a614bbf1)
#         ;
#
#
#
#
#             var marker_bcfc06b1de147e9eafea795ad21625b6 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_1e61f6ade344f2af60217e7797c0cc42);
#
#
#         var popup_46cdca5d405ab1b1321a423472107858 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_26abb099d06a8c82b8c86b5ae8207025 = $(`&lt;div id=&quot;html_26abb099d06a8c82b8c86b5ae8207025&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_46cdca5d405ab1b1321a423472107858.setContent(html_26abb099d06a8c82b8c86b5ae8207025);
#
#
#         marker_bcfc06b1de147e9eafea795ad21625b6.bindPopup(popup_46cdca5d405ab1b1321a423472107858)
#         ;
#
#
#
#
#             var marker_54a338b5091b3fe31a1e15268538ace5 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_1e61f6ade344f2af60217e7797c0cc42);
#
#
#         var popup_4c6b4eb0b83a767b7d339ef85c8a3e05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_407cbb83db87d1197d950b4fb2ffabcc = $(`&lt;div id=&quot;html_407cbb83db87d1197d950b4fb2ffabcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_4c6b4eb0b83a767b7d339ef85c8a3e05.setContent(html_407cbb83db87d1197d950b4fb2ffabcc);
#
#
#         marker_54a338b5091b3fe31a1e15268538ace5.bindPopup(popup_4c6b4eb0b83a767b7d339ef85c8a3e05)
#         ;
#
#
#
#
#             var marker_7e78cb9a49ecf1349479a76f6ae9f380 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_1e61f6ade344f2af60217e7797c0cc42);
#
#
#         var popup_dd9ab31fb3fd548de4914381fcdf06ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5e5182649f6fba0866df78c652ab8185 = $(`&lt;div id=&quot;html_5e5182649f6fba0866df78c652ab8185&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_dd9ab31fb3fd548de4914381fcdf06ec.setContent(html_5e5182649f6fba0866df78c652ab8185);
#
#
#         marker_7e78cb9a49ecf1349479a76f6ae9f380.bindPopup(popup_dd9ab31fb3fd548de4914381fcdf06ec)
#         ;
#
#
#
#
#             var marker_a60243c987b70c6a13a375e4d362ed7c = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_1e61f6ade344f2af60217e7797c0cc42);
#
#
#         var popup_df40524f074e12fcf74466b04f4e5f68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5f5d41a2e20ec620002f1bc372088597 = $(`&lt;div id=&quot;html_5f5d41a2e20ec620002f1bc372088597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_df40524f074e12fcf74466b04f4e5f68.setContent(html_5f5d41a2e20ec620002f1bc372088597);
#
#
#         marker_a60243c987b70c6a13a375e4d362ed7c.bindPopup(popup_df40524f074e12fcf74466b04f4e5f68)
#         ;
#
#
#
#
#             var marker_374e7b0f2eba26a8a22fac517f2b66d3 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_1e61f6ade344f2af60217e7797c0cc42);
#
#
#         var popup_bdd46a41ff2

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('..\Master\combined_loc.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %%
df
# Out:
#            Datum                      brand  \
# 0     21.09.2020          Alpina Tankstelle
# 1     21.09.2020          Alpina Tankstelle
# 2     21.09.2020          Alpina Tankstelle
# 3     21.09.2020          Alpina Tankstelle
# 4     21.09.2020          Alpina Tankstelle
# ...          ...                        ...
# 2408  04.05.2016  Auto Bellinzona Nord Sagl
# 2409  02.02.2016                  Reisch AG
# 2410  04.05.2016                Auto Lugano
# 2411  22.12.2020               Ruedi Rüssel
# 2412  22.12.2020        Dorfgarage Willi AG
#
#                                    addresse  diesel  bleifrei        lat  \
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# 1         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# 2         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# 3         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# 4         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# ...                                     ...     ...       ...        ...
# 2408   Via S. Gottardo 57B, 6500 Bellinzona   1.320     1.330  46.203907
# 2409       Hauptstr. 24, 8573 Siegershausen   1.320     1.270  47.611435
# 2410           Via Cantonale, 6983 Magliaso   1.319     1.279  45.985931
# 2411           Luzernstr. 60, 4553 Subingen   1.310     1.260  47.193531
# 2412     Rheintalstrasse 59, 5325 Leibstadt   1.300     1.250  47.591080
#
#             lon
# 0     10.358743
# 1     10.358743
# 2     10.358743
# 3     10.358743
# 4     10.358743
# ...         ...
# 2408   9.034014
# 2409   9.169731
# 2410   8.891774
# 2411   7.621964
# 2412   8.175756
#
# [2413 rows x 7 columns]

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2022-12-22 13:28:53
# Python Version: 3.9.5
# -----------------------------------

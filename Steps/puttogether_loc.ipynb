# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import math
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing diesel data

# %%
# Read the data to a pandas data frame
df_diesel = pd.read_csv('..\data\Diesel.csv', 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_diesel
# Out:
#             date                     brand  \
# 0     21.09.2020         Alpina Tankstelle
# 1     04.07.2022                       Eni
# 2     15.06.2022                    Tamoil
# 3     02.06.2022  BP Service Weinland West
# 4     02.06.2022   BP Service Weinland Ost
# ...          ...                       ...
# 2600  04.05.2016               Auto Lugano
# 2601  26.12.2020           Lang Energie AG
# 2602  22.12.2020              Ruedi Rüssel
# 2603  22.12.2020       Dorfgarage Willi AG
# 2604  21.09.2020         Alpina Tankstelle
#
#                                      adress  diesel
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120
# 1             Rte d'Aigle 18, 1867 Ollon VD   2.450
# 2      Rte du Nant-d'Avril 36, 1214 Vernier   2.440
# 3     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# 4     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# ...                                     ...     ...
# 2600           Via Cantonale, 6983 Magliaso   1.319
# 2601           Seestr. 13, 8280 Kreuzlingen   1.310
# 2602           Luzernstr. 60, 4553 Subingen   1.310
# 2603     Rheintalstrasse 59, 5325 Leibstadt   1.300
# 2604      Dorfstrasse 42, 7563 Samnaun Dorf   1.120
#
# [2605 rows x 4 columns]

# %% [markdown]
# # Importing bleifrei data

# %%
# Read the data to a pandas data frame
df_bleifrei = pd.read_csv("..\data\Bleifrei.csv", 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_bleifrei
# Out:
#             date                                brand  \
# 0     21.09.2020                    Alpina Tankstelle
# 1     04.07.2022                               Tamoil
# 2     04.07.2022                               Agrola
# 3     04.07.2022                    Garage Blatter AG
# 4     11.07.2022                     Garage Gasparini
# ...          ...                                  ...
# 2599  22.12.2020                         Ruedi Rüssel
# 2600  22.12.2020                  Dorfgarage Willi AG
# 2601  24.07.2016                        Garage Jaques
# 2602  27.11.2020  Hansruedi Julmi Garage & Tankstelle
# 2603  21.09.2020                    Alpina Tankstelle
#
#                                      adress  bleifrei
# 0         Dorfstrasse 42, 7563 Samnaun Dorf      1.14
# 1     Gsteigstr. 174, 3785 Gsteig b. Gstaad      2.23
# 2               Kantonsstr. 50, 3930 Eyholz      2.23
# 3                 Ennet Brücke 7, 3930 Visp      2.23
# 4                  Veia Granda, 7440 Andeer      2.23
# ...                                     ...       ...
# 2599           Luzernstr. 60, 4553 Subingen      1.26
# 2600     Rheintalstrasse 59, 5325 Leibstadt      1.25
# 2601           Route de Lausanne, 1260 Nyon      1.25
# 2602         Bielstrasse 85, 2542 Pieterlen      1.25
# 2603      Dorfstrasse 42, 7563 Samnaun Dorf      1.14
#
# [2604 rows x 4 columns]

# %%
df = pd.merge(df_diesel, df_bleifrei, on=['date','adress'])

df = df.drop(columns=['brand_y'])
df = df.rename(columns={"brand_x":"brand", "adress":"address", "diesel":"diesel_price", "bleifrei":"bleifrei_price"})
df = df.dropna()
df = df.drop_duplicates()

df
# Out:
#             date                      brand  \
# 0     21.09.2020          Alpina Tankstelle
# 16    28.10.2022             Socar Gotthard
# 17    14.08.2022                BP Rheintal
# 18    11.07.2022     eni - Castasegna Ovest
# 19    03.08.2022                         BP
# ...          ...                        ...
# 2444  04.05.2016  Auto Bellinzona Nord Sagl
# 2445  02.02.2016                  Reisch AG
# 2446  04.05.2016                Auto Lugano
# 2447  22.12.2020               Ruedi Rüssel
# 2448  22.12.2020        Dorfgarage Willi AG
#
#                                       address  diesel_price  bleifrei_price
# 0           Dorfstrasse 42, 7563 Samnaun Dorf         1.120           1.140
# 16                   A2 West, 6467 Schattdorf         2.395           2.035
# 17                Autobahn A13, 9470 Buchs SG         2.380           2.200
# 18                   Farzett, 7608 Castasegna         2.380           2.230
# 19    Grüningerstr. 80, 8624 Grüt (Gossau ZH)         2.370           2.220
# ...                                       ...           ...             ...
# 2444     Via S. Gottardo 57B, 6500 Bellinzona         1.320           1.330
# 2445         Hauptstr. 24, 8573 Siegershausen         1.320           1.270
# 2446             Via Cantonale, 6983 Magliaso         1.319           1.279
# 2447             Luzernstr. 60, 4553 Subingen         1.310           1.260
# 2448       Rheintalstrasse 59, 5325 Leibstadt         1.300           1.250
#
# [2405 rows x 5 columns]

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['address'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['address']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['address'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
# Out:
# Geocoding address 2405 out of 2405 : Rheintalstrasse 59, 5325 Leibstadt

# %%
counter=0
count=0
count2=0

for i in df['lat']:
    if math.isnan(i):
        count = count + 1
    else:
        count2 = count2 + 1
        
    counter = counter + 1
    
print(count)
print(count2)
# Out:
# 647
# 1758

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['address']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_418dc3335a59ceee87449bbf0dbf9c4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_418dc3335a59ceee87449bbf0dbf9c4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_418dc3335a59ceee87449bbf0dbf9c4d = L.map(
#                 &quot;map_418dc3335a59ceee87449bbf0dbf9c4d&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79f972e3f57f9f7551f1075177e3fac6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_418dc3335a59ceee87449bbf0dbf9c4d);
#
#
#             var marker_ba51abaae0b24979b062ea92c085598a = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_418dc3335a59ceee87449bbf0dbf9c4d);
#
#
#         var popup_da83773ea43b22d5da7f1b3f22f6ec3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_10f9d171c150982d4168448c74c1e75a = $(`&lt;div id=&quot;html_10f9d171c150982d4168448c74c1e75a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_da83773ea43b22d5da7f1b3f22f6ec3e.setContent(html_10f9d171c150982d4168448c74c1e75a);
#
#
#         marker_ba51abaae0b24979b062ea92c085598a.bindPopup(popup_da83773ea43b22d5da7f1b3f22f6ec3e)
#         ;
#
#
#
#
#             var marker_3ce41a92a4319438c1aa533fab4d7b1f = L.marker(
#                 [47.2286491394043, 7.621632099151611],
#                 {}
#             ).addTo(map_418dc3335a59ceee87449bbf0dbf9c4d);
#
#
#         var popup_fb8ca830466de4bab4b3bfc42f787a0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d0e13f90f73df41fa4754695bb8c74f9 = $(`&lt;div id=&quot;html_d0e13f90f73df41fa4754695bb8c74f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A2 West, 6467 Schattdorf&lt;/div&gt;`)[0];
#             popup_fb8ca830466de4bab4b3bfc42f787a0b.setContent(html_d0e13f90f73df41fa4754695bb8c74f9);
#
#
#         marker_3ce41a92a4319438c1aa533fab4d7b1f.bindPopup(popup_fb8ca830466de4bab4b3bfc42f787a0b)
#         ;
#
#
#
#
#             var marker_126d2531a60a770cbadc8959af816a5f = L.marker(
#                 [47.28566360473633, 8.563126564025879],
#                 {}
#             ).addTo(map_418dc3335a59ceee87449bbf0dbf9c4d);
#
#
#         var popup_7e3eadfa63c11ebbfc3a16b4a346bd03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1b2343e14f24e442f00da96a0ed558e7 = $(`&lt;div id=&quot;html_1b2343e14f24e442f00da96a0ed558e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Farzett, 7608 Castasegna&lt;/div&gt;`)[0];
#             popup_7e3eadfa63c11ebbfc3a16b4a346bd03.setContent(html_1b2343e14f24e442f00da96a0ed558e7);
#
#
#         marker_126d2531a60a770cbadc8959af816a5f.bindPopup(popup_7e3eadfa63c11ebbfc3a16b4a346bd03)
#         ;
#
#
#
#
#             var marker_85758de36db56efaffdcf1c39b662338 = L.marker(
#                 [47.448482513427734, 8.926337242126465],
#                 {}
#             ).addTo(map_418dc3335a59ceee87449bbf0dbf9c4d);
#
#
#         var popup_59f12764cb78bbe3366e4ae9c5e9d277 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1c770fb6da05368d36819a9bd6b8a84c = $(`&lt;div id=&quot;html_1c770fb6da05368d36819a9bd6b8a84c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grüningerstr. 80, 8624 Grüt (Gossau ZH)&lt;/div&gt;`)[0];
#             popup_59f12764cb78bbe3366e4ae9c5e9d277.setContent(html_1c770fb6da05368d36819a9bd6b8a84c);
#
#
#         marker_85758de36db56efaffdcf1c39b662338.bindPopup(popup_59f12764cb78bbe3366e4ae9c5e9d277)
#         ;
#
#
#
#
#             var marker_5b06942f47e64150bff0d66e325ca3fb = L.marker(
#                 [47.46453094482422, 8.969184875488281],
#                 {}
#             ).addTo(map_418dc3335a59ceee87449bbf0dbf9c4d);
#
#
#         var popup_56ad2f9de6d3568165195129c6471d09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_55412ce5c3fd7a6eb7b2041772c9d892 = $(`&lt;div id=&quot;html_55412ce5c3fd7a6eb7b2041772c9d892&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Av. de Mategnin 16, 1217 Meyrin&lt;/div&gt;`)[0];
#             popup_56ad2f9de6d3568165195129c6471d09.setContent(html_55412ce5c3fd7a6eb7b2041772c9d892);
#
#
#         marker_5b06942f47e64150bff0d66e325ca3fb.bindPopup(popup_56ad2f9de6d3568165195129c6471d09)
#         ;
#
#
#
#
#             var marker_f7d09625c882b95b878fc9a4444ada20 = L.marker(
#                 [46.8580207824707, 8.642415046691895],
#                 {}
#             ).addTo(map_418dc3335a59ceee87449bbf0dbf9c4d);
#
#
#         var popup_85d45c4d916515149328dbde84

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('..\Master\combined_loc.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2022-12-22 20:00:53
# Python Version: 3.9.5
# -----------------------------------

# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import math
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing diesel data

# %%
# Read the data to a pandas data frame
df_diesel = pd.read_csv('..\data\Diesel.csv', 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_diesel
# Out:
#            Datum                     brand  \
# 0     21.09.2020         Alpina Tankstelle
# 1     04.07.2022                       Eni
# 2     15.06.2022                    Tamoil
# 3     02.06.2022  BP Service Weinland West
# 4     02.06.2022   BP Service Weinland Ost
# ...          ...                       ...
# 2600  04.05.2016               Auto Lugano
# 2601  26.12.2020           Lang Energie AG
# 2602  22.12.2020              Ruedi Rüssel
# 2603  22.12.2020       Dorfgarage Willi AG
# 2604  21.09.2020         Alpina Tankstelle
#
#                                    addresse  diesel
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120
# 1             Rte d'Aigle 18, 1867 Ollon VD   2.450
# 2      Rte du Nant-d'Avril 36, 1214 Vernier   2.440
# 3     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# 4     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# ...                                     ...     ...
# 2600           Via Cantonale, 6983 Magliaso   1.319
# 2601           Seestr. 13, 8280 Kreuzlingen   1.310
# 2602           Luzernstr. 60, 4553 Subingen   1.310
# 2603     Rheintalstrasse 59, 5325 Leibstadt   1.300
# 2604      Dorfstrasse 42, 7563 Samnaun Dorf   1.120
#
# [2605 rows x 4 columns]

# %% [markdown]
# # Importing bleifrei data

# %%
# Read the data to a pandas data frame
df_bleifrei = pd.read_csv("..\data\Bleifrei.csv", 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_bleifrei
# Out:
#            Datum                                brand  \
# 0     21.09.2020                    Alpina Tankstelle
# 1     04.07.2022                               Tamoil
# 2     04.07.2022                               Agrola
# 3     04.07.2022                    Garage Blatter AG
# 4     11.07.2022                     Garage Gasparini
# ...          ...                                  ...
# 2599  22.12.2020                         Ruedi Rüssel
# 2600  22.12.2020                  Dorfgarage Willi AG
# 2601  24.07.2016                        Garage Jaques
# 2602  27.11.2020  Hansruedi Julmi Garage & Tankstelle
# 2603  21.09.2020                    Alpina Tankstelle
#
#                                    addresse  bleifrei
# 0         Dorfstrasse 42, 7563 Samnaun Dorf      1.14
# 1     Gsteigstr. 174, 3785 Gsteig b. Gstaad      2.23
# 2               Kantonsstr. 50, 3930 Eyholz      2.23
# 3                 Ennet Brücke 7, 3930 Visp      2.23
# 4                  Veia Granda, 7440 Andeer      2.23
# ...                                     ...       ...
# 2599           Luzernstr. 60, 4553 Subingen      1.26
# 2600     Rheintalstrasse 59, 5325 Leibstadt      1.25
# 2601           Route de Lausanne, 1260 Nyon      1.25
# 2602         Bielstrasse 85, 2542 Pieterlen      1.25
# 2603      Dorfstrasse 42, 7563 Samnaun Dorf      1.14
#
# [2604 rows x 4 columns]

# %%
df = df_diesel.merge(df_bleifrei)

df
# Out:
#            Datum                      brand  \
# 0     21.09.2020          Alpina Tankstelle
# 1     21.09.2020          Alpina Tankstelle
# 2     21.09.2020          Alpina Tankstelle
# 3     21.09.2020          Alpina Tankstelle
# 4     21.09.2020          Alpina Tankstelle
# ...          ...                        ...
# 2408  04.05.2016  Auto Bellinzona Nord Sagl
# 2409  02.02.2016                  Reisch AG
# 2410  04.05.2016                Auto Lugano
# 2411  22.12.2020               Ruedi Rüssel
# 2412  22.12.2020        Dorfgarage Willi AG
#
#                                    addresse  diesel  bleifrei
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 1         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 2         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 3         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 4         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# ...                                     ...     ...       ...
# 2408   Via S. Gottardo 57B, 6500 Bellinzona   1.320     1.330
# 2409       Hauptstr. 24, 8573 Siegershausen   1.320     1.270
# 2410           Via Cantonale, 6983 Magliaso   1.319     1.279
# 2411           Luzernstr. 60, 4553 Subingen   1.310     1.260
# 2412     Rheintalstrasse 59, 5325 Leibstadt   1.300     1.250
#
# [2413 rows x 5 columns]

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['addresse'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['addresse']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['addresse'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
# Out:
# Geocoding address 2413 out of 2413 : Rheintalstrasse 59, 5325 Leibstadt

# %%
counter=0;
count=0;
count2=0;

for i in df['lat']:
    if math.isnan(i):
        count = count + 1
    else:
        count2 = count2 + 1
        
    counter = counter + 1
    
print(count)
print(count2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\gianz\OneDrive\Dokumente\GitHub\TS\Steps\puttogether_loc.ipynb Cell 11 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> count=0;
#       <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> count2=0;
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> for i in df['lat']:
#       <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a>     if math.isnan(i):
#       <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a>         count = count + 1
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'lat'

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['addresse']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\gianz\OneDrive\Dokumente\GitHub\TS\Steps\puttogether_loc.ipynb Cell 13 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> df_sub = df.dropna()
#       <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> for i in range(0, len(df_sub)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     folium.Marker(location=(df_sub.iloc[i]['lat'],
#       <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>                             df_sub.iloc[i]['lon']),
#       <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>                   popup=df_sub.iloc[i]['addresse']).add_to(m)
#      <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a> # Layer control
#      <a href='vscode-notebook-cell:/c%3A/Users/gianz/OneDrive/Dokumente/GitHub/TS/Steps/puttogether_loc.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a> folium.LayerControl().add_to(m)
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\gianz\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'lat'

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('..\Master\combined_loc.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %%
df

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2022-12-22 12:19:34
# Python Version: 3.9.13
# -----------------------------------

# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import math
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing diesel data

# %%
# Read the data to a pandas data frame
df_diesel = pd.read_csv('..\data\Diesel.csv', 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_diesel
# Out:
#             date                     brand  \
# 0     21.09.2020         Alpina Tankstelle
# 1     04.07.2022                       Eni
# 2     15.06.2022                    Tamoil
# 3     02.06.2022  BP Service Weinland West
# 4     02.06.2022   BP Service Weinland Ost
# ...          ...                       ...
# 2600  04.05.2016               Auto Lugano
# 2601  26.12.2020           Lang Energie AG
# 2602  22.12.2020              Ruedi Rüssel
# 2603  22.12.2020       Dorfgarage Willi AG
# 2604  21.09.2020         Alpina Tankstelle
#
#                                      adress  diesel
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120
# 1             Rte d'Aigle 18, 1867 Ollon VD   2.450
# 2      Rte du Nant-d'Avril 36, 1214 Vernier   2.440
# 3     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# 4     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# ...                                     ...     ...
# 2600           Via Cantonale, 6983 Magliaso   1.319
# 2601           Seestr. 13, 8280 Kreuzlingen   1.310
# 2602           Luzernstr. 60, 4553 Subingen   1.310
# 2603     Rheintalstrasse 59, 5325 Leibstadt   1.300
# 2604      Dorfstrasse 42, 7563 Samnaun Dorf   1.120
#
# [2605 rows x 4 columns]

# %% [markdown]
# # Importing bleifrei data

# %%
# Read the data to a pandas data frame
df_bleifrei = pd.read_csv("..\data\Bleifrei.csv", 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_bleifrei
# Out:
#             date                                brand  \
# 0     21.09.2020                    Alpina Tankstelle
# 1     04.07.2022                               Tamoil
# 2     04.07.2022                               Agrola
# 3     04.07.2022                    Garage Blatter AG
# 4     11.07.2022                     Garage Gasparini
# ...          ...                                  ...
# 2599  22.12.2020                         Ruedi Rüssel
# 2600  22.12.2020                  Dorfgarage Willi AG
# 2601  24.07.2016                        Garage Jaques
# 2602  27.11.2020  Hansruedi Julmi Garage & Tankstelle
# 2603  21.09.2020                    Alpina Tankstelle
#
#                                      adress  bleifrei
# 0         Dorfstrasse 42, 7563 Samnaun Dorf      1.14
# 1     Gsteigstr. 174, 3785 Gsteig b. Gstaad      2.23
# 2               Kantonsstr. 50, 3930 Eyholz      2.23
# 3                 Ennet Brücke 7, 3930 Visp      2.23
# 4                  Veia Granda, 7440 Andeer      2.23
# ...                                     ...       ...
# 2599           Luzernstr. 60, 4553 Subingen      1.26
# 2600     Rheintalstrasse 59, 5325 Leibstadt      1.25
# 2601           Route de Lausanne, 1260 Nyon      1.25
# 2602         Bielstrasse 85, 2542 Pieterlen      1.25
# 2603      Dorfstrasse 42, 7563 Samnaun Dorf      1.14
#
# [2604 rows x 4 columns]

# %%
df = pd.merge(df_diesel, df_bleifrei, on=['date','adress'])

df = df.drop(columns=['brand_y'])
df = df.rename(columns={"brand_x":"brand", "adress":"address", "diesel":"diesel_price", "bleifrei":"bleifrei_price"})
df = df.dropna()
df = df.drop_duplicates()

df
# Out:
#             date                      brand  \
# 0     21.09.2020          Alpina Tankstelle
# 16    28.10.2022             Socar Gotthard
# 17    14.08.2022                BP Rheintal
# 18    11.07.2022     eni - Castasegna Ovest
# 19    03.08.2022                         BP
# ...          ...                        ...
# 2444  04.05.2016  Auto Bellinzona Nord Sagl
# 2445  02.02.2016                  Reisch AG
# 2446  04.05.2016                Auto Lugano
# 2447  22.12.2020               Ruedi Rüssel
# 2448  22.12.2020        Dorfgarage Willi AG
#
#                                       address  diesel_price  bleifrei_price
# 0           Dorfstrasse 42, 7563 Samnaun Dorf         1.120           1.140
# 16                   A2 West, 6467 Schattdorf         2.395           2.035
# 17                Autobahn A13, 9470 Buchs SG         2.380           2.200
# 18                   Farzett, 7608 Castasegna         2.380           2.230
# 19    Grüningerstr. 80, 8624 Grüt (Gossau ZH)         2.370           2.220
# ...                                       ...           ...             ...
# 2444     Via S. Gottardo 57B, 6500 Bellinzona         1.320           1.330
# 2445         Hauptstr. 24, 8573 Siegershausen         1.320           1.270
# 2446             Via Cantonale, 6983 Magliaso         1.319           1.279
# 2447             Luzernstr. 60, 4553 Subingen         1.310           1.260
# 2448       Rheintalstrasse 59, 5325 Leibstadt         1.300           1.250
#
# [2405 rows x 5 columns]

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['address'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['address']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['address'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
# Out:
# Geocoding address 2405 out of 2405 : Rheintalstrasse 59, 5325 Leibstadt

# %%
counter=0;
count=0;
count2=0;

for i in df['lat']:
    if math.isnan(i):
        count = count + 1
    else:
        count2 = count2 + 1
        
    counter = counter + 1
    
print(count)
print(count2)
# Out:
# 647
# 1758

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['address']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_599b636dc25a8e5643fd7b7be099b2ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_599b636dc25a8e5643fd7b7be099b2ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_599b636dc25a8e5643fd7b7be099b2ea = L.map(
#                 &quot;map_599b636dc25a8e5643fd7b7be099b2ea&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b66946bca4ba13321efb41ccbe9b3d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_599b636dc25a8e5643fd7b7be099b2ea);
#
#
#             var marker_6df9dc9b6df947a8d4b96dd520507c7b = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_599b636dc25a8e5643fd7b7be099b2ea);
#
#
#         var popup_7e834f6408d90e046abc599b065bda32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_697a9d155a5088f3f6c887917864120e = $(`&lt;div id=&quot;html_697a9d155a5088f3f6c887917864120e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_7e834f6408d90e046abc599b065bda32.setContent(html_697a9d155a5088f3f6c887917864120e);
#
#
#         marker_6df9dc9b6df947a8d4b96dd520507c7b.bindPopup(popup_7e834f6408d90e046abc599b065bda32)
#         ;
#
#
#
#
#             var marker_deaf8d54a3400886bf9c6bf0abb9f057 = L.marker(
#                 [47.2286491394043, 7.621632099151611],
#                 {}
#             ).addTo(map_599b636dc25a8e5643fd7b7be099b2ea);
#
#
#         var popup_f77836c9fe930cb452efcaddcc8ba5a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_edc0e6e08d5cd1981fdb87451637b28d = $(`&lt;div id=&quot;html_edc0e6e08d5cd1981fdb87451637b28d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A2 West, 6467 Schattdorf&lt;/div&gt;`)[0];
#             popup_f77836c9fe930cb452efcaddcc8ba5a8.setContent(html_edc0e6e08d5cd1981fdb87451637b28d);
#
#
#         marker_deaf8d54a3400886bf9c6bf0abb9f057.bindPopup(popup_f77836c9fe930cb452efcaddcc8ba5a8)
#         ;
#
#
#
#
#             var marker_241cbde4c56729d8611e4ce0042fa9dc = L.marker(
#                 [47.28566360473633, 8.563126564025879],
#                 {}
#             ).addTo(map_599b636dc25a8e5643fd7b7be099b2ea);
#
#
#         var popup_50f13175b5cec45c90ccb714014b857d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_07e474be7b896aef5cea8ff81b49349f = $(`&lt;div id=&quot;html_07e474be7b896aef5cea8ff81b49349f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Farzett, 7608 Castasegna&lt;/div&gt;`)[0];
#             popup_50f13175b5cec45c90ccb714014b857d.setContent(html_07e474be7b896aef5cea8ff81b49349f);
#
#
#         marker_241cbde4c56729d8611e4ce0042fa9dc.bindPopup(popup_50f13175b5cec45c90ccb714014b857d)
#         ;
#
#
#
#
#             var marker_6d8a148d5a7c9eb3b5068a1c24b2f518 = L.marker(
#                 [47.448482513427734, 8.926337242126465],
#                 {}
#             ).addTo(map_599b636dc25a8e5643fd7b7be099b2ea);
#
#
#         var popup_83919393c779d241833e80f1c4d84f92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9d6064faa2b8af54003e32c77951512c = $(`&lt;div id=&quot;html_9d6064faa2b8af54003e32c77951512c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grüningerstr. 80, 8624 Grüt (Gossau ZH)&lt;/div&gt;`)[0];
#             popup_83919393c779d241833e80f1c4d84f92.setContent(html_9d6064faa2b8af54003e32c77951512c);
#
#
#         marker_6d8a148d5a7c9eb3b5068a1c24b2f518.bindPopup(popup_83919393c779d241833e80f1c4d84f92)
#         ;
#
#
#
#
#             var marker_b2942055e414bac6f6009c36b924ddad = L.marker(
#                 [47.46453094482422, 8.969184875488281],
#                 {}
#             ).addTo(map_599b636dc25a8e5643fd7b7be099b2ea);
#
#
#         var popup_af98ece81d64bdf6c916cb0da2c441ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ee82be0ff615ff73a9d318645036013c = $(`&lt;div id=&quot;html_ee82be0ff615ff73a9d318645036013c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Av. de Mategnin 16, 1217 Meyrin&lt;/div&gt;`)[0];
#             popup_af98ece81d64bdf6c916cb0da2c441ca.setContent(html_ee82be0ff615ff73a9d318645036013c);
#
#
#         marker_b2942055e414bac6f6009c36b924ddad.bindPopup(popup_af98ece81d64bdf6c916cb0da2c441ca)
#         ;
#
#
#
#
#             var marker_69c4459f7bcc301bb590001c4ca72731 = L.marker(
#                 [46.8580207824707, 8.642415046691895],
#                 {}
#             ).addTo(map_599b636dc25a8e5643fd7b7be099b2ea);
#
#
#         var popup_1a99a46fef991d766f610029c4

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('..\Master\combined_loc.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %%
df
# Out:
#            Datum                      brand  \
# 0     21.09.2020          Alpina Tankstelle
# 1     21.09.2020          Alpina Tankstelle
# 2     21.09.2020          Alpina Tankstelle
# 3     21.09.2020          Alpina Tankstelle
# 4     21.09.2020          Alpina Tankstelle
# ...          ...                        ...
# 2408  04.05.2016  Auto Bellinzona Nord Sagl
# 2409  02.02.2016                  Reisch AG
# 2410  04.05.2016                Auto Lugano
# 2411  22.12.2020               Ruedi Rüssel
# 2412  22.12.2020        Dorfgarage Willi AG
#
#                                    addresse  diesel  bleifrei        lat  \
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# 1         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# 2         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# 3         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# 4         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140  46.943104
# ...                                     ...     ...       ...        ...
# 2408   Via S. Gottardo 57B, 6500 Bellinzona   1.320     1.330  46.203907
# 2409       Hauptstr. 24, 8573 Siegershausen   1.320     1.270  47.611435
# 2410           Via Cantonale, 6983 Magliaso   1.319     1.279  45.985931
# 2411           Luzernstr. 60, 4553 Subingen   1.310     1.260  47.193531
# 2412     Rheintalstrasse 59, 5325 Leibstadt   1.300     1.250  47.591080
#
#             lon
# 0     10.358743
# 1     10.358743
# 2     10.358743
# 3     10.358743
# 4     10.358743
# ...         ...
# 2408   9.034014
# 2409   9.169731
# 2410   8.891774
# 2411   7.621964
# 2412   8.175756
#
# [2413 rows x 7 columns]

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2022-12-22 19:33:00
# Python Version: 3.9.5
# -----------------------------------

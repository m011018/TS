# %%
# Libraries
import os
import sqlite3
import re
import time
import fnmatch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('..\data\Diesel_TS_raw_excel.csv',
                 sep=';',
                 encoding='latin-1')

# %%
# Extract values from 'price_raw' strings
brand = []
addresse = []
for i in df['Adresse']:
    d1 = i.split("\r\n\r\n")
    brand.append(d1[0])
    try:
        addresse.append(d1[1])
    except:
        addresse.append("keine")

# Save as new variable in the pandas data frame
df['brand'] = brand
df['addresse'] = addresse

df
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0        1671562663-17  https://www.benzin-preis.ch/suche-kanton?next=...
# 1        1671562666-18  https://www.benzin-preis.ch/suche-kanton?next=...
# 2        1671562668-19  https://www.benzin-preis.ch/suche-kanton?next=...
# 3        1671562670-20  https://www.benzin-preis.ch/suche-kanton?next=...
# 4        1671562672-21  https://www.benzin-preis.ch/suche-kanton?next=...
# ...                ...                                                ...
# 2616   1671569189-2647    https://www.benzin-preis.ch/suche-kanton?next=5
# 2617   1671569192-2648    https://www.benzin-preis.ch/suche-kanton?next=4
# 2618   1671569194-2649    https://www.benzin-preis.ch/suche-kanton?next=3
# 2619   1671569196-2650    https://www.benzin-preis.ch/suche-kanton?next=2
# 2620   1671569199-2651    https://www.benzin-preis.ch/suche-kanton?next=1
#
#                                                 Adresse     Art       Datum  \
# 0     Alpina Tankstelle\r\n\r\nDorfstrasse 42, 7563 ...  Diesel  21.09.2020
# 1              Eni\r\n\r\nRte d'Aigle 18, 1867 Ollon VD  Diesel  04.07.2022
# 2     Tamoil\r\n\r\nRte du Nant-d'Avril 36, 1214 Ver...  Diesel  15.06.2022
# 3     BP Service Weinland West\r\n\r\nA4 Ausfahrt An...  Diesel  02.06.2022
# 4     BP Service Weinland Ost\r\n\r\nA4 Ausfahrt And...  Diesel  02.06.2022
# ...                                                 ...     ...         ...
# 2616    Auto Lugano\r\n\r\nVia Cantonale, 6983 Magliaso  Diesel  04.05.2016
# 2617  Lang Energie AG\r\n\r\nSeestr. 13, 8280 Kreuzl...  Diesel  26.12.2020
# 2618   Ruedi Rüssel\r\n\r\nLuzernstr. 60, 4553 Subingen  Diesel  22.12.2020
# 2619  Dorfgarage Willi AG\r\n\r\nRheintalstrasse 59,...  Diesel  22.12.2020
# 2620  Alpina Tankstelle\r\n\r\nDorfstrasse 42, 7563 ...  Diesel  21.09.2020
#
#           Preis     Preis2                     brand  \
# 0     1,120 sFr  1,767 sFr         Alpina Tankstelle
# 1     2,450 sFr  2,187 sFr                       Eni
# 2     2,440 sFr  2,167 sFr                    Tamoil
# 3     2,439 sFr  2,266 sFr  BP Service Weinland West
# 4     2,439 sFr  2,266 sFr   BP Service Weinland Ost
# ...         ...        ...                       ...
# 2616  1,319 sFr        NaN               Auto Lugano
# 2617  1,310 sFr  1,827 sFr           Lang Energie AG
# 2618  1,310 sFr  1,907 sFr              Ruedi Rüssel
# 2619  1,300 sFr  1,897 sFr       Dorfgarage Willi AG
# 2620  1,120 sFr  1,767 sFr         Alpina Tankstelle
#
#                                    addresse
# 0         Dorfstrasse 42, 7563 Samnaun Dorf
# 1             Rte d'Aigle 18, 1867 Ollon VD
# 2      Rte du Nant-d'Avril 36, 1214 Vernier
# 3     A4 Ausfahrt Andelfingen, 8452 Adlikon
# 4     A4 Ausfahrt Andelfingen, 8452 Adlikon
# ...                                     ...
# 2616           Via Cantonale, 6983 Magliaso
# 2617           Seestr. 13, 8280 Kreuzlingen
# 2618           Luzernstr. 60, 4553 Subingen
# 2619     Rheintalstrasse 59, 5325 Leibstadt
# 2620      Dorfstrasse 42, 7563 Samnaun Dorf
#
# [2621 rows x 9 columns]

# %%
counter=0;
count=0;

for i in df['addresse']:
    if i == "keine":
        df = df.drop(labels=counter, axis=0)
        count = count + 1
    counter = counter + 1
    
print(count)
# Out:
# 16

# %%
# Extract values from 'price_raw' strings
price = []
for i in df['Preis']:
    d1 = "".join(c for c in i if  c.isdecimal())
    price.append((int(d1) / 1000))

# Save as new variable in the pandas data frame
df['diesel'] = price

# %%
df.drop(columns=['Preis','Art','Adresse','Preis2','web-scraper-order','web-scraper-start-url'], inplace=True, axis=1)

# %%
df
# Out:
#            Datum                     brand  \
# 0     21.09.2020         Alpina Tankstelle
# 1     04.07.2022                       Eni
# 2     15.06.2022                    Tamoil
# 3     02.06.2022  BP Service Weinland West
# 4     02.06.2022   BP Service Weinland Ost
# ...          ...                       ...
# 2616  04.05.2016               Auto Lugano
# 2617  26.12.2020           Lang Energie AG
# 2618  22.12.2020              Ruedi Rüssel
# 2619  22.12.2020       Dorfgarage Willi AG
# 2620  21.09.2020         Alpina Tankstelle
#
#                                    addresse  diesel
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120
# 1             Rte d'Aigle 18, 1867 Ollon VD   2.450
# 2      Rte du Nant-d'Avril 36, 1214 Vernier   2.440
# 3     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# 4     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# ...                                     ...     ...
# 2616           Via Cantonale, 6983 Magliaso   1.319
# 2617           Seestr. 13, 8280 Kreuzlingen   1.310
# 2618           Luzernstr. 60, 4553 Subingen   1.310
# 2619     Rheintalstrasse 59, 5325 Leibstadt   1.300
# 2620      Dorfstrasse 42, 7563 Samnaun Dorf   1.120
#
# [2605 rows x 4 columns]

# %%
df.to_csv('..\data\diesel.csv', 
          sep=",", 
          encoding='utf-8',
          index=False)

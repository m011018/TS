# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import sqlite3
import requests
import json
import urllib
import fnmatch
import folium
import math
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing diesel data

# %%
# Read the data to a pandas data frame
df_diesel = pd.read_csv('data/diesel.csv', 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_diesel
# Out:
#             date                     brand  \
# 0     21.09.2020         Alpina Tankstelle
# 1     04.07.2022                       Eni
# 2     15.06.2022                    Tamoil
# 3     02.06.2022  BP Service Weinland West
# 4     02.06.2022   BP Service Weinland Ost
# ...          ...                       ...
# 2600  04.05.2016               Auto Lugano
# 2601  26.12.2020           Lang Energie AG
# 2602  22.12.2020              Ruedi Rüssel
# 2603  22.12.2020       Dorfgarage Willi AG
# 2604  21.09.2020         Alpina Tankstelle
#
#                                      adress  diesel
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120
# 1             Rte d'Aigle 18, 1867 Ollon VD   2.450
# 2      Rte du Nant-d'Avril 36, 1214 Vernier   2.440
# 3     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# 4     A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# ...                                     ...     ...
# 2600           Via Cantonale, 6983 Magliaso   1.319
# 2601           Seestr. 13, 8280 Kreuzlingen   1.310
# 2602           Luzernstr. 60, 4553 Subingen   1.310
# 2603     Rheintalstrasse 59, 5325 Leibstadt   1.300
# 2604      Dorfstrasse 42, 7563 Samnaun Dorf   1.120
#
# [2605 rows x 4 columns]

# %% [markdown]
# # Importing bleifrei data

# %%
# Read the data to a pandas data frame
df_bleifrei = pd.read_csv("data/bleifrei.csv", 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_bleifrei
# Out:
#             date                                brand  \
# 0     21.09.2020                    Alpina Tankstelle
# 1     04.07.2022                               Tamoil
# 2     04.07.2022                               Agrola
# 3     04.07.2022                    Garage Blatter AG
# 4     11.07.2022                     Garage Gasparini
# ...          ...                                  ...
# 2599  22.12.2020                         Ruedi Rüssel
# 2600  22.12.2020                  Dorfgarage Willi AG
# 2601  24.07.2016                        Garage Jaques
# 2602  27.11.2020  Hansruedi Julmi Garage & Tankstelle
# 2603  21.09.2020                    Alpina Tankstelle
#
#                                      adress  bleifrei
# 0         Dorfstrasse 42, 7563 Samnaun Dorf      1.14
# 1     Gsteigstr. 174, 3785 Gsteig b. Gstaad      2.23
# 2               Kantonsstr. 50, 3930 Eyholz      2.23
# 3                 Ennet Brücke 7, 3930 Visp      2.23
# 4                  Veia Granda, 7440 Andeer      2.23
# ...                                     ...       ...
# 2599           Luzernstr. 60, 4553 Subingen      1.26
# 2600     Rheintalstrasse 59, 5325 Leibstadt      1.25
# 2601           Route de Lausanne, 1260 Nyon      1.25
# 2602         Bielstrasse 85, 2542 Pieterlen      1.25
# 2603      Dorfstrasse 42, 7563 Samnaun Dorf      1.14
#
# [2604 rows x 4 columns]

# %%
df = pd.merge(df_diesel, df_bleifrei, on=['date','adress'])

df = df.drop(columns=['brand_y'])
df = df.rename(columns={"brand_x":"brand", "adress":"address", "diesel":"diesel_price", "bleifrei":"bleifrei_price"})
df = df.dropna()
df = df.drop_duplicates()

df
# Out:
#             date                      brand  \
# 0     21.09.2020          Alpina Tankstelle
# 16    28.10.2022             Socar Gotthard
# 17    14.08.2022                BP Rheintal
# 18    11.07.2022     eni - Castasegna Ovest
# 19    03.08.2022                         BP
# ...          ...                        ...
# 2444  04.05.2016  Auto Bellinzona Nord Sagl
# 2445  02.02.2016                  Reisch AG
# 2446  04.05.2016                Auto Lugano
# 2447  22.12.2020               Ruedi Rüssel
# 2448  22.12.2020        Dorfgarage Willi AG
#
#                                       address  diesel_price  bleifrei_price
# 0           Dorfstrasse 42, 7563 Samnaun Dorf         1.120           1.140
# 16                   A2 West, 6467 Schattdorf         2.395           2.035
# 17                Autobahn A13, 9470 Buchs SG         2.380           2.200
# 18                   Farzett, 7608 Castasegna         2.380           2.230
# 19    Grüningerstr. 80, 8624 Grüt (Gossau ZH)         2.370           2.220
# ...                                       ...           ...             ...
# 2444     Via S. Gottardo 57B, 6500 Bellinzona         1.320           1.330
# 2445         Hauptstr. 24, 8573 Siegershausen         1.320           1.270
# 2446             Via Cantonale, 6983 Magliaso         1.319           1.279
# 2447             Luzernstr. 60, 4553 Subingen         1.310           1.260
# 2448       Rheintalstrasse 59, 5325 Leibstadt         1.300           1.250
#
# [2405 rows x 5 columns]

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['address'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['address']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['address'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
# Out:
# Geocoding address 2405 out of 2405 : Rheintalstrasse 59, 5325 Leibstadt

# %%
counter=0
count=0
count2=0

for i in df['lat']:
    if math.isnan(i):
        count = count + 1
    else:
        count2 = count2 + 1
        
    counter = counter + 1
    
print(count)
print(count2)
# Out:
# 647
# 1758

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['address']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ceff4370daa33bf22605232ff9f65f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ceff4370daa33bf22605232ff9f65f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ceff4370daa33bf22605232ff9f65f6 = L.map(
#                 &quot;map_0ceff4370daa33bf22605232ff9f65f6&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_936ddfe5ce87f44d5374ba38a77849ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0ceff4370daa33bf22605232ff9f65f6);
#
#
#             var marker_a3ef9bfa12293b84536e78016a0a6502 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_0ceff4370daa33bf22605232ff9f65f6);
#
#
#         var popup_5e3e6c834f066827dde37dbea251faa6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e47064d49080e554bb9d908cd871aa43 = $(`&lt;div id=&quot;html_e47064d49080e554bb9d908cd871aa43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#                 popup_5e3e6c834f066827dde37dbea251faa6.setContent(html_e47064d49080e554bb9d908cd871aa43);
#
#
#
#         marker_a3ef9bfa12293b84536e78016a0a6502.bindPopup(popup_5e3e6c834f066827dde37dbea251faa6)
#         ;
#
#
#
#
#             var marker_e3a40034263480468ee609a9233fbc9b = L.marker(
#                 [47.2286491394043, 7.621632099151611],
#                 {}
#             ).addTo(map_0ceff4370daa33bf22605232ff9f65f6);
#
#
#         var popup_b2a15a77e06d427acb72982e4a6a6723 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3cb3aba1a66be6f7831dd966d03af70 = $(`&lt;div id=&quot;html_c3cb3aba1a66be6f7831dd966d03af70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A2 West, 6467 Schattdorf&lt;/div&gt;`)[0];
#                 popup_b2a15a77e06d427acb72982e4a6a6723.setContent(html_c3cb3aba1a66be6f7831dd966d03af70);
#
#
#
#         marker_e3a40034263480468ee609a9233fbc9b.bindPopup(popup_b2a15a77e06d427acb72982e4a6a6723)
#         ;
#
#
#
#
#             var marker_842ce4d1199a7a6f23a0a4bb1f9ceb09 = L.marker(
#                 [47.28566360473633, 8.563126564025879],
#                 {}
#             ).addTo(map_0ceff4370daa33bf22605232ff9f65f6);
#
#
#         var popup_db5cf02b15dc5bb1fce7374da368380f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61c424db175a3d31b9f2f572dc74f61b = $(`&lt;div id=&quot;html_61c424db175a3d31b9f2f572dc74f61b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Farzett, 7608 Castasegna&lt;/div&gt;`)[0];
#                 popup_db5cf02b15dc5bb1fce7374da368380f.setContent(html_61c424db175a3d31b9f2f572dc74f61b);
#
#
#
#         marker_842ce4d1199a7a6f23a0a4bb1f9ceb09.bindPopup(popup_db5cf02b15dc5bb1fce7374da368380f)
#         ;
#
#
#
#
#             var marker_926f8f238314c6d41cf47ebeaa427c1e = L.marker(
#                 [47.448482513427734, 8.926337242126465],
#                 {}
#             ).addTo(map_0ceff4370daa33bf22605232ff9f65f6);
#
#
#         var popup_eb5a3d83b22261fc8683c895d4221ba1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f88b6fecfb033af79e2a0620e85d7cf = $(`&lt;div id=&quot;html_4f88b6fecfb033af79e2a0620e85d7cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grüningerstr. 80, 8624 Grüt (Gossau ZH)&lt;/div&gt;`)[0];
#                 popup_eb5a3d83b22261fc8683c895d4221ba1.setContent(html_4f88b6fecfb033af79e2a0620e85d7cf);
#
#
#
#         marker_926f8f238314c6d41cf47ebeaa427c1e.bindPopup(popup_eb5a3d83b22261fc8683c895d4221ba1)
#         ;
#
#
#
#
#             var marker_c25703425a8a91c21322c0981db29554 = L.marker(
#                 [47.46453094482422, 8.969184875488281],
#                 {}
#             ).addTo(map_0ceff4370daa33bf22605232ff9f65f6);
#
#
#         var popup_679ca03d38d50a69ae015e6a81e64c30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8ac030d8d059a3dfeefa4dd4e633884 = $(`&lt;div id=&quot;html_a8ac030d8d059a3dfeefa4dd4e633884&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Av. de Mategnin 16, 1217 Meyrin&lt;/div&gt;`)[0];
#                 popup_679ca03d38d50a69ae015e6a81e64c30.setContent(html_a8ac030d8d059a3dfeefa4dd4e633884);
#
#
#
#         marker_c25703425a8a91c21322c0981db29554.bindPopup(popup_679ca03d38d50a69ae015e6a81e64c3

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('Master/combined_loc.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %%
# Get current working directory
print(os.getcwd())

# Create data base
conn = sqlite3.connect('Master/fuel_database.db') 
cursor = conn.cursor()

# Show dbs in the directory
flist = fnmatch.filter(os.listdir('.'), '*.db')
for i in flist:
    print(i)
# Out:
# c:\Users\calvi\OneDrive\Dokumente\GitHub\TS

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS fuel_table ( date VARCHAR(50),
                                                                brand VARCHAR(50),
                                                                address VARCHAR(50),
                                                                diesel_price DECIMAL(4,3),
                                                                bleifrei_price DECIMAL(4,3),
                                                                lat DECIMAL(4,3),
                                                                lon DECIMAL(4,3))''')
# Confirm changes to the table
conn.commit()

# %%
df.to_sql(name = 'fuel_table',
          con = conn,
          index = False,
          if_exists = 'replace')
# Out:
# 2405

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2022-12-24 16:53:27
# Python Version: 3.11.0
# -----------------------------------

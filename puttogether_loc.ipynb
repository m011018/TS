# %% [markdown]
# # Geocoding apartment addresses using the geoadmin API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import urllib
import fnmatch
import folium
import math
import pandas as pd
from IPython.display import clear_output

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing diesel data

# %%
# Read the data to a pandas data frame
df_diesel = pd.read_csv('diesel.csv', 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_diesel.head(5)
# Out:
#         Datum                     brand  \
# 0  21.09.2020         Alpina Tankstelle
# 1  04.07.2022                       Eni
# 2  15.06.2022                    Tamoil
# 3  02.06.2022  BP Service Weinland West
# 4  02.06.2022   BP Service Weinland Ost
#
#                                 addresse  diesle
# 0      Dorfstrasse 42, 7563 Samnaun Dorf   1.120
# 1          Rte d'Aigle 18, 1867 Ollon VD   2.450
# 2   Rte du Nant-d'Avril 36, 1214 Vernier   2.440
# 3  A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439
# 4  A4 Ausfahrt Andelfingen, 8452 Adlikon   2.439

# %% [markdown]
# # Importing bleifrei data

# %%
# Read the data to a pandas data frame
df_bleifrei = pd.read_csv('bleifrei.csv', 
                 sep=',', 
                 encoding='utf-8')

# Show first records
df_bleifrei.head(5)
# Out:
#         Datum              brand                               addresse  \
# 0  21.09.2020  Alpina Tankstelle      Dorfstrasse 42, 7563 Samnaun Dorf
# 1  04.07.2022             Tamoil  Gsteigstr. 174, 3785 Gsteig b. Gstaad
# 2  04.07.2022             Agrola            Kantonsstr. 50, 3930 Eyholz
# 3  04.07.2022  Garage Blatter AG              Ennet Brücke 7, 3930 Visp
# 4  11.07.2022   Garage Gasparini               Veia Granda, 7440 Andeer
#
#    bleifrei
# 0      1.14
# 1      2.23
# 2      2.23
# 3      2.23
# 4      2.23

# %%
df = df_diesel.merge(df_bleifrei)

df
# Out:
#            Datum                      brand  \
# 0     21.09.2020          Alpina Tankstelle
# 1     21.09.2020          Alpina Tankstelle
# 2     21.09.2020          Alpina Tankstelle
# 3     21.09.2020          Alpina Tankstelle
# 4     21.09.2020          Alpina Tankstelle
# ...          ...                        ...
# 2408  04.05.2016  Auto Bellinzona Nord Sagl
# 2409  02.02.2016                  Reisch AG
# 2410  04.05.2016                Auto Lugano
# 2411  22.12.2020               Ruedi Rüssel
# 2412  22.12.2020        Dorfgarage Willi AG
#
#                                    addresse  diesle  bleifrei
# 0         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 1         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 2         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 3         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# 4         Dorfstrasse 42, 7563 Samnaun Dorf   1.120     1.140
# ...                                     ...     ...       ...
# 2408   Via S. Gottardo 57B, 6500 Bellinzona   1.320     1.330
# 2409       Hauptstr. 24, 8573 Siegershausen   1.320     1.270
# 2410           Via Cantonale, 6983 Magliaso   1.319     1.279
# 2411           Luzernstr. 60, 4553 Subingen   1.310     1.260
# 2412     Rheintalstrasse 59, 5325 Leibstadt   1.300     1.250
#
# [2413 rows x 5 columns]

# %% [markdown]
# ### Geocoding multiple apartment addresses using the geoadmin API

# %%
# Define base url
base_url= "https://api3.geo.admin.ch/rest/services/api/SearchServer?"

# Geocode list of adresses
geolocation = []
n = 1
for i in df['addresse'].astype(str):
    
    print('Geocoding address', 
          n, 
          'out of', 
          len(df['addresse']), 
          ':', 
          i)
    n=n+1
    clear_output(wait=True)
    
    try:
        # Set up search parameters - address, origins and type
        parameters = {"searchText": i,
                      "origins": "address",
                      "type": "locations",
                     }

        # Server request
        r = requests.get(f"{base_url}{urllib.parse.urlencode(parameters)}")

        # Get data
        data = json.loads(r.content)

        # Take first server response, convert to df with relevant infos
        df_loc = pd.DataFrame.from_dict(list(data.values())[0][0], 
                                        orient='columns')
        geolocation.append(df_loc.iloc[[5,6],0].astype(float))
    
    except:
        geolocation.append(pd.Series(data={'lat': None, 'lon': None}))
        
        

# Write lat and lon to df
df_loc = pd.DataFrame(geolocation, 
                      columns=("lat", "lon"), 
                      index=range(len(df['addresse'])))
df['lat'] = df_loc['lat']
df['lon'] = df_loc['lon']
# Out:
# Geocoding address 302 out of 2413 : Hubelgutstrasse 1, 3048 Worblaufen

# %%
counter=0;
count=0;
count2=0;

for i in df['lat']:
    if math.isnan(i):
        count = count + 1
    else:
        count2 = count2 + 1
        
    counter = counter + 1
    
print(count)
print(count2)
# Out:
# 619
# 1794

# %% [markdown]
# ### Plot addresses on map

# %%
# Initialisierung der Map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
df_sub = df.dropna()
for i in range(0, len(df_sub)):
    folium.Marker(location=(df_sub.iloc[i]['lat'], 
                            df_sub.iloc[i]['lon']), 
                  popup=df_sub.iloc[i]['addresse']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53f5a0b9c9f53a0d916369615c902241 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53f5a0b9c9f53a0d916369615c902241&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_53f5a0b9c9f53a0d916369615c902241 = L.map(
#                 &quot;map_53f5a0b9c9f53a0d916369615c902241&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_767f6fda4bb82bb6e58875341d0c7857 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_53f5a0b9c9f53a0d916369615c902241);
#
#
#             var marker_e7583a0f0f780ab6136378585d4c154b = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_53f5a0b9c9f53a0d916369615c902241);
#
#
#         var popup_bc365da8490c5042b538741e2e28d1bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f1ca06852015ae064f2ff8c0d63fb97d = $(`&lt;div id=&quot;html_f1ca06852015ae064f2ff8c0d63fb97d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_bc365da8490c5042b538741e2e28d1bb.setContent(html_f1ca06852015ae064f2ff8c0d63fb97d);
#
#
#         marker_e7583a0f0f780ab6136378585d4c154b.bindPopup(popup_bc365da8490c5042b538741e2e28d1bb)
#         ;
#
#
#
#
#             var marker_fbdbbb54cb7310b77f3e8a7fe2794e4f = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_53f5a0b9c9f53a0d916369615c902241);
#
#
#         var popup_95706275c31c94e5047ed451ce2be55f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_83b3bf8348e680e5f4fe0fce4cccb83c = $(`&lt;div id=&quot;html_83b3bf8348e680e5f4fe0fce4cccb83c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_95706275c31c94e5047ed451ce2be55f.setContent(html_83b3bf8348e680e5f4fe0fce4cccb83c);
#
#
#         marker_fbdbbb54cb7310b77f3e8a7fe2794e4f.bindPopup(popup_95706275c31c94e5047ed451ce2be55f)
#         ;
#
#
#
#
#             var marker_79a11d7fa147361237e654b851f816e4 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_53f5a0b9c9f53a0d916369615c902241);
#
#
#         var popup_6918016a9f544a0ec42ad3a06310ae72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_42a8eb519408b22767175a08747e1d43 = $(`&lt;div id=&quot;html_42a8eb519408b22767175a08747e1d43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_6918016a9f544a0ec42ad3a06310ae72.setContent(html_42a8eb519408b22767175a08747e1d43);
#
#
#         marker_79a11d7fa147361237e654b851f816e4.bindPopup(popup_6918016a9f544a0ec42ad3a06310ae72)
#         ;
#
#
#
#
#             var marker_a9c318cf6b5eff6a03ffe1864a8b8128 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_53f5a0b9c9f53a0d916369615c902241);
#
#
#         var popup_711922931d410935ce0b0cafa63a788b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_484903fb5fd2f1306a77c5bb662380da = $(`&lt;div id=&quot;html_484903fb5fd2f1306a77c5bb662380da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_711922931d410935ce0b0cafa63a788b.setContent(html_484903fb5fd2f1306a77c5bb662380da);
#
#
#         marker_a9c318cf6b5eff6a03ffe1864a8b8128.bindPopup(popup_711922931d410935ce0b0cafa63a788b)
#         ;
#
#
#
#
#             var marker_65402dca82645040b5be4cd9b74552e4 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_53f5a0b9c9f53a0d916369615c902241);
#
#
#         var popup_451351a7552ca2f59497561286a8504a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_34fcd41d08333d896dd3ce1f500e1792 = $(`&lt;div id=&quot;html_34fcd41d08333d896dd3ce1f500e1792&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dorfstrasse 42, 7563 Samnaun Dorf&lt;/div&gt;`)[0];
#             popup_451351a7552ca2f59497561286a8504a.setContent(html_34fcd41d08333d896dd3ce1f500e1792);
#
#
#         marker_65402dca82645040b5be4cd9b74552e4.bindPopup(popup_451351a7552ca2f59497561286a8504a)
#         ;
#
#
#
#
#             var marker_2f25fb88f35acd10748860bdb26ecf66 = L.marker(
#                 [46.9431037902832, 10.358742713928223],
#                 {}
#             ).addTo(map_53f5a0b9c9f53a0d916369615c902241);
#
#
#         var popup_f208f02ea8c911e70751c50fb0d

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('komplett_with_loc.csv', 
           sep=",", 
           encoding='utf-8',
           index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2022-12-22 12:19:34
# Python Version: 3.9.13
# -----------------------------------
